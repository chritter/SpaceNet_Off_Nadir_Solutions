# %% [markdown]
# # Neural Network Properties
#
# ### Goals
#
# * The goal is to understand the network properties
# * Estimate flops and compute time before execution
# * Estimate memory usage before computation
#
# ### Comments
#
# * All this information will help to commpare different models

# %%
from zoo.models import SeResNext50_9ch_Unet

# %%
model = SeResNext50_9ch_Unet()
model.children()
# Out:
# Downloading: "http://data.lip6.fr/cadene/pretrainedmodels/se_resnext50_32x4d-a260b3a4.pth" to /Users/christian/.cache/torch/checkpoints/se_resnext50_32x4d-a260b3a4.pth
# 100%|██████████| 105M/105M [05:11<00:00, 355kB/s]
# <generator object Module.children at 0x125eec468>
